# %%
import pandas as pd

# %%
df = pd.read_csv('regression.csv')

# %%
df.head()
# Out:
#    Year Month Cost Centre  Account Account Description Account Type    Amount
# 0  2019   Jan       CC100  1000000       Product Sales      Revenue  1344.051
# 1  2019   Jan       CC100  1000001   Licensing Revenue      Revenue   480.968
# 2  2019   Jan       CC100  1000002     Service Revenue      Revenue   650.820
# 3  2019   Jan       CC100  1000004         Fee Revenue      Revenue   339.360
# 4  2019   Jan       CC100  2000000   Cost of Good Sold      Expense  1125.328

# %%
df.tail()
# Out:
#       Year Month Cost Centre  Account  Account Description Account Type  \
# 4207  2021   Dec       CC302  2000005            Purchases      Expense
# 4208  2021   Dec       CC302  3000000         Cash at Bank        Asset
# 4209  2021   Dec       CC302  3000001            Inventory        Asset
# 4210  2021   Dec       CC302  3000002  Accounts Receivable        Asset
# 4211  2021   Dec       CC302  4000001     Accounts Payable    Liability
#
#         Amount
# 4207   698.121
# 4208  -282.056
# 4209   537.478
# 4210  1152.680
# 4211 -1020.000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4212 entries, 0 to 4211
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 4212 non-null   int64
#  1   Month                4212 non-null   object
#  2   Cost Centre          4212 non-null   object
#  3   Account              4212 non-null   int64
#  4   Account Description  4212 non-null   object
#  5   Account Type         4212 non-null   object
#  6   Amount               4212 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 230.5+ KB

# %%
for col in df.columns:
    print(col, len(df[col].unique()), df[col].unique())
# Out:
# Year 3 [2019 2020 2021]
# Month 12 ['Jan' 'Feb' 'Mar' 'Apr' 'May' 'Jun' 'Jul' 'Aug' 'Sep' 'Oct' 'Nov' 'Dec']
# Cost Centre 9 ['CC100' 'CC101' 'CC102' 'CC200' 'CC201' 'CC202' 'CC300' 'CC301' 'CC302']
# Account 13 [1000000 1000001 1000002 1000004 2000000 2000001 2000002 2000003 2000005
#  3000000 3000001 3000002 4000001]
# Account Description 13 ['Product Sales' 'Licensing Revenue' 'Service Revenue' 'Fee Revenue'
#  'Cost of Good Sold' 'Staff Expenses' 'Technology Expenses'
#  'Property Expenses' 'Purchases' 'Cash at Bank' 'Inventory'
#  'Accounts Receivable' 'Accounts Payable']
# Account Type 4 ['Revenue' 'Expense' 'Asset' 'Liability']
# Amount 3956 [1344.051  480.968  650.82  ... -282.056  537.478 1152.68 ]

# %%
df.describe()
# Out:
#               Year       Account       Amount
# count  4212.000000  4.212000e+03  4212.000000
# mean   2020.000000  2.076925e+06   476.470421
# std       0.816594  9.167528e+05   477.296234
# min    2019.000000  1.000000e+06 -1020.000000
# 25%    2019.000000  1.000004e+06   268.044500
# 50%    2020.000000  2.000002e+06   512.998500
# 75%    2021.000000  3.000000e+06   755.960250
# max    2021.000000  4.000001e+06  2378.880000

# %%
df.dtypes
# Out:
# Year                     int64
# Month                   object
# Cost Centre             object
# Account                  int64
# Account Description     object
# Account Type            object
# Amount                 float64
# dtype: object

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,6))
sns.violinplot(x='Account Type', y='Amount', data=df).set_title('Account Type ViolinPlot')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.violinplot(x='Account', y='Amount', data=df[df['Account Type']=='Liability']).set_title('Liability ViolinPlot')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.violinplot(x='Account Description', y='Amount', data=df[df['Account Type']=='Revenue']).set_title('Liability ViolinPlot')
plt.show()

# %%
df.head()
# Out:
#    Year Month Cost Centre  Account Account Description Account Type    Amount
# 0  2019   Jan       CC100  1000000       Product Sales      Revenue  1344.051
# 1  2019   Jan       CC100  1000001   Licensing Revenue      Revenue   480.968
# 2  2019   Jan       CC100  1000002     Service Revenue      Revenue   650.820
# 3  2019   Jan       CC100  1000004         Fee Revenue      Revenue   339.360
# 4  2019   Jan       CC100  2000000   Cost of Good Sold      Expense  1125.328

# %%
monthmap = {
    'Jan':1,
    'Feb':2,
    'Mar':3,
    'Apr':4,
    'May':5,
    'Jun':6,
    'Jul':7,
    'Aug':8,
    'Sep':9,
    'Oct':10,
    'Nov':11,
    'Dec':12,
}

# %%
monthmap['Jan']
# Out:
# 1

# %%
df['Period'] = df['Month'].apply(lambda x: monthmap[x])

# %%
df['Day'] = 1

# %%
df['Date'] = df['Year'].astype(str) + '-' + df['Period'].astype(str) + '-' + df['Day'].astype(str)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Year                            int64
# Month                          object
# Cost Centre                    object
# Account                         int64
# Account Description            object
# Account Type                   object
# Amount                        float64
# Period                          int64
# Day                             int64
# Date                   datetime64[ns]
# dtype: object

# %%
plt.figure(figsize=(20,6))
sns.lineplot(x='Date', y='Amount', hue='Account Description', estimator=None, data=df[df['Account Type']=='Revenue']).set_title('Seasonal Sales')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.lineplot(x='Date', y='Amount', hue='Account Description', estimator=None, data=df[df['Account Description']=='Product Sales']).set_title('Seasonal Sales')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.lineplot(x='Date', y='Amount', hue='Account Description', estimator=None, data=df[df['Account Description']=='Service Revenue']).set_title('Seasonal Sales')
plt.show()

# %%
#df.corr()

# %%
df['Account Description'].unique()
# Out:
# array(['Product Sales', 'Licensing Revenue', 'Service Revenue',
#        'Fee Revenue', 'Cost of Good Sold', 'Staff Expenses',
#        'Technology Expenses', 'Property Expenses', 'Purchases',
#        'Cash at Bank', 'Inventory', 'Accounts Receivable',
#        'Accounts Payable'], dtype=object)

# %%
pd.get_dummies(df['Account'])
# Out:
#       1000000  1000001  1000002  1000004  2000000  2000001  2000002  2000003  \
# 0        True    False    False    False    False    False    False    False
# 1       False     True    False    False    False    False    False    False
# 2       False    False     True    False    False    False    False    False
# 3       False    False    False     True    False    False    False    False
# 4       False    False    False    False     True    False    False    False
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 4207    False    False    False    False    False    False    False    False
# 4208    False    False    False    False    False    False    False    False
# 4209    False    False    False    False    False    False    False    False
# 4210    False    False    False    False    False    False    False    False
# 4211    False    False    False    False    False    False    False    False
#
#       2000005  3000000  3000001  3000002  4000001
# 0       False    False    False    False    False
# 1       False    False    False    False    False
# 2       False    False    False    False    False
# 3       False    False    False    False    False
# 4       False    False    False    False    False
# ...       ...      ...      ...      ...      ...
# 4207     True    False    False    False    False
# 4208    False     True    False    False    False
# 4209    False    False     True    False    False
# 4210    False    False    False     True    False
# 4211    False    False    False    False     True
#
# [4212 rows x 13 columns]

# %%
corrdict = {}
for key, row in df.join(pd.get_dummies(df['Account'])).iterrows():
    corrdict[key] = {int(row['Account']):row['Amount']}

# %%
corrdf = pd.DataFrame.from_dict(corrdict).T.fillna(0)

# %%
corrdf.corr()
# Out:
#           1000000   1000001   1000002   1000004   2000000   2000001   2000002  \
# 1000000  1.000000 -0.058293 -0.065252 -0.064706 -0.061763 -0.066141 -0.065989
# 1000001 -0.058293  1.000000 -0.060742 -0.060233 -0.057494 -0.061569 -0.061428
# 1000002 -0.065252 -0.060742  1.000000 -0.067424 -0.064358 -0.068920 -0.068762
# 1000004 -0.064706 -0.060233 -0.067424  1.000000 -0.063819 -0.068343 -0.068186
# 2000000 -0.061763 -0.057494 -0.064358 -0.063819  1.000000 -0.065235 -0.065085
# 2000001 -0.066141 -0.061569 -0.068920 -0.068343 -0.065235  1.000000 -0.069699
# 2000002 -0.065989 -0.061428 -0.068762 -0.068186 -0.065085 -0.069699  1.000000
# 2000003 -0.065547 -0.061016 -0.068301 -0.067728 -0.064648 -0.069231 -0.069072
# 2000005 -0.061377 -0.057135 -0.063956 -0.063420 -0.060536 -0.064827 -0.064679
# 3000000  0.007528  0.007007  0.007844  0.007778  0.007424  0.007951  0.007933
# 3000001 -0.070332 -0.065471 -0.073287 -0.072673 -0.069369 -0.074286 -0.074115
# 3000002 -0.060539 -0.056355 -0.063083 -0.062555 -0.059710 -0.063942 -0.063796
# 4000001  0.010549  0.009820  0.010992  0.010900  0.010404  0.011142  0.011116
#
#           2000003   2000005   3000000   3000001   3000002   4000001
# 1000000 -0.065547 -0.061377  0.007528 -0.070332 -0.060539  0.010549
# 1000001 -0.061016 -0.057135  0.007007 -0.065471 -0.056355  0.009820
# 1000002 -0.068301 -0.063956  0.007844 -0.073287 -0.063083  0.010992
# 1000004 -0.067728 -0.063420  0.007778 -0.072673 -0.062555  0.010900
# 2000000 -0.064648 -0.060536  0.007424 -0.069369 -0.059710  0.010404
# 2000001 -0.069231 -0.064827  0.007951 -0.074286 -0.063942  0.011142
# 2000002 -0.069072 -0.064679  0.007933 -0.074115 -0.063796  0.011116
# 2000003  1.000000 -0.064244  0.007879 -0.073618 -0.063368  0.011041
# 2000005 -0.064244  1.000000  0.007378 -0.068935 -0.059337  0.010339
# 3000000  0.007879  0.007378  1.000000  0.008455  0.007277 -0.001268
# 3000001 -0.073618 -0.068935  0.008455  1.000000 -0.067994  0.011848
# 3000002 -0.063368 -0.059337  0.007277 -0.067994  1.000000  0.010198
# 4000001  0.011041  0.010339 -0.001268  0.011848  0.010198  1.000000

# %%
plt.figure(figsize=(20,6))
sns.heatmap(corrdf.corr()).set_title('Account Correlation')
plt.show()

# %%
df[df['Account']==3000000]
# Out:
#       Year Month Cost Centre  Account Account Description Account Type  \
# 9     2019   Jan       CC100  3000000        Cash at Bank        Asset
# 22    2019   Jan       CC101  3000000        Cash at Bank        Asset
# 35    2019   Jan       CC102  3000000        Cash at Bank        Asset
# 48    2019   Jan       CC200  3000000        Cash at Bank        Asset
# 61    2019   Jan       CC201  3000000        Cash at Bank        Asset
# ...    ...   ...         ...      ...                 ...          ...
# 4156  2021   Dec       CC201  3000000        Cash at Bank        Asset
# 4169  2021   Dec       CC202  3000000        Cash at Bank        Asset
# 4182  2021   Dec       CC300  3000000        Cash at Bank        Asset
# 4195  2021   Dec       CC301  3000000        Cash at Bank        Asset
# 4208  2021   Dec       CC302  3000000        Cash at Bank        Asset
#
#        Amount  Period  Day       Date
# 9     476.713       1    1 2019-01-01
# 22    464.197       1    1 2019-01-01
# 35   -296.261       1    1 2019-01-01
# 48    750.000       1    1 2019-01-01
# 61    187.647       1    1 2019-01-01
# ...       ...     ...  ...        ...
# 4156  413.616      12    1 2021-12-01
# 4169  375.657      12    1 2021-12-01
# 4182 -492.546      12    1 2021-12-01
# 4195 -579.986      12    1 2021-12-01
# 4208 -282.056      12    1 2021-12-01
#
# [324 rows x 10 columns]

# %%
df[df['Account']==4000001]
# Out:
#       Year Month Cost Centre  Account Account Description Account Type  \
# 12    2019   Jan       CC100  4000001    Accounts Payable    Liability
# 25    2019   Jan       CC101  4000001    Accounts Payable    Liability
# 38    2019   Jan       CC102  4000001    Accounts Payable    Liability
# 51    2019   Jan       CC200  4000001    Accounts Payable    Liability
# 64    2019   Jan       CC201  4000001    Accounts Payable    Liability
# ...    ...   ...         ...      ...                 ...          ...
# 4159  2021   Dec       CC201  4000001    Accounts Payable    Liability
# 4172  2021   Dec       CC202  4000001    Accounts Payable    Liability
# 4185  2021   Dec       CC300  4000001    Accounts Payable    Liability
# 4198  2021   Dec       CC301  4000001    Accounts Payable    Liability
# 4211  2021   Dec       CC302  4000001    Accounts Payable    Liability
#
#       Amount  Period  Day       Date
# 12     980.0       1    1 2019-01-01
# 25     200.0       1    1 2019-01-01
# 38    -980.0       1    1 2019-01-01
# 51     980.0       1    1 2019-01-01
# 64     784.0       1    1 2019-01-01
# ...      ...     ...  ...        ...
# 4159   804.0      12    1 2021-12-01
# 4172 -1018.0      12    1 2021-12-01
# 4185 -1020.0      12    1 2021-12-01
# 4198  -612.0      12    1 2021-12-01
# 4211 -1020.0      12    1 2021-12-01
#
# [324 rows x 10 columns]

# %%
import numpy as np

# %%
for account in df['Account'].unique():
    plt.figure(figsize=(20,6))
    sns.lineplot(x='Date', y='Amount', estimator=np.median, hue='Account Description', data=df[df['Account']==account]).set_title('{} by Month'.format(account))
    plt.show()

# %%
#df = df[df['Account']!=3000001]

# %%
df['Account'].unique()
# Out:
# array([1000000, 1000001, 1000002, 1000004, 2000000, 2000001, 2000002,
#        2000003, 2000005, 3000000, 3000001, 3000002, 4000001])

# %%
df.dtypes
# Out:
# Year                            int64
# Month                          object
# Cost Centre                    object
# Account                         int64
# Account Description            object
# Account Type                   object
# Amount                        float64
# Period                          int64
# Day                             int64
# Date                   datetime64[ns]
# dtype: object

# %%
df['Account'] = 'ACC' + df['Account'].astype(str)

# %%
df.head()
# Out:
#    Year Month Cost Centre     Account Account Description Account Type  \
# 0  2019   Jan       CC100  ACC1000000       Product Sales      Revenue
# 1  2019   Jan       CC100  ACC1000001   Licensing Revenue      Revenue
# 2  2019   Jan       CC100  ACC1000002     Service Revenue      Revenue
# 3  2019   Jan       CC100  ACC1000004         Fee Revenue      Revenue
# 4  2019   Jan       CC100  ACC2000000   Cost of Good Sold      Expense
#
#      Amount  Period  Day       Date
# 0  1344.051       1    1 2019-01-01
# 1   480.968       1    1 2019-01-01
# 2   650.820       1    1 2019-01-01
# 3   339.360       1    1 2019-01-01
# 4  1125.328       1    1 2019-01-01

# %%
df.dtypes
# Out:
# Year                            int64
# Month                          object
# Cost Centre                    object
# Account                        object
# Account Description            object
# Account Type                   object
# Amount                        float64
# Period                          int64
# Day                             int64
# Date                   datetime64[ns]
# dtype: object

# %%
df['Year'] = df['Year'].astype(str)

# %%
df.dtypes
# Out:
# Year                           object
# Month                          object
# Cost Centre                    object
# Account                        object
# Account Description            object
# Account Type                   object
# Amount                        float64
# Period                          int64
# Day                             int64
# Date                   datetime64[ns]
# dtype: object

# %%
df.drop(['Period', 'Day', 'Date'], axis=1, inplace=True)

# %%
df.dtypes
# Out:
# Year                    object
# Month                   object
# Cost Centre             object
# Account                 object
# Account Description     object
# Account Type            object
# Amount                 float64
# dtype: object

# %%
len(df['Account'].unique())
# Out:
# 13

# %%
len(df['Account Description'].unique())
# Out:
# 13

# %%
df['AccountVal'] = df['Account'] + df['Account Description']

# %%
df.head()
# Out:
#    Year Month Cost Centre     Account Account Description Account Type  \
# 0  2019   Jan       CC100  ACC1000000       Product Sales      Revenue
# 1  2019   Jan       CC100  ACC1000001   Licensing Revenue      Revenue
# 2  2019   Jan       CC100  ACC1000002     Service Revenue      Revenue
# 3  2019   Jan       CC100  ACC1000004         Fee Revenue      Revenue
# 4  2019   Jan       CC100  ACC2000000   Cost of Good Sold      Expense
#
#      Amount                   AccountVal
# 0  1344.051      ACC1000000Product Sales
# 1   480.968  ACC1000001Licensing Revenue
# 2   650.820    ACC1000002Service Revenue
# 3   339.360        ACC1000004Fee Revenue
# 4  1125.328  ACC2000000Cost of Good Sold

# %%
len(df['AccountVal'].unique())
# Out:
# 13

# %%
df.drop(['Account Description', 'AccountVal'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Year Month Cost Centre     Account Account Type    Amount
# 0  2019   Jan       CC100  ACC1000000      Revenue  1344.051
# 1  2019   Jan       CC100  ACC1000001      Revenue   480.968
# 2  2019   Jan       CC100  ACC1000002      Revenue   650.820
# 3  2019   Jan       CC100  ACC1000004      Revenue   339.360
# 4  2019   Jan       CC100  ACC2000000      Expense  1125.328

# %%
pd.get_dummies(df)
# Out:
#         Amount  Year_2019  Year_2020  Year_2021  Month_Apr  Month_Aug  \
# 0     1344.051       True      False      False      False      False
# 1      480.968       True      False      False      False      False
# 2      650.820       True      False      False      False      False
# 3      339.360       True      False      False      False      False
# 4     1125.328       True      False      False      False      False
# ...        ...        ...        ...        ...        ...        ...
# 4207   698.121      False      False       True      False      False
# 4208  -282.056      False      False       True      False      False
# 4209   537.478      False      False       True      False      False
# 4210  1152.680      False      False       True      False      False
# 4211 -1020.000      False      False       True      False      False
#
#       Month_Dec  Month_Feb  Month_Jan  Month_Jul  ...  Account_ACC2000003  \
# 0         False      False       True      False  ...               False
# 1         False      False       True      False  ...               False
# 2         False      False       True      False  ...               False
# 3         False      False       True      False  ...               False
# 4         False      False       True      False  ...               False
# ...         ...        ...        ...        ...  ...                 ...
# 4207       True      False      False      False  ...               False
# 4208       True      False      False      False  ...               False
# 4209       True      False      False      False  ...               False
# 4210       True      False      False      False  ...               False
# 4211       True      False      False      False  ...               False
#
#       Account_ACC2000005  Account_ACC3000000  Account_ACC3000001  \
# 0                  False               False               False
# 1                  False               False               False
# 2                  False               False               False
# 3                  False               False               False
# 4                  False               False               False
# ...                  ...                 ...                 ...
# 4207                True               False               False
# 4208               False                True               False
# 4209               False               False                True
# 4210               False               False               False
# 4211               False               False               False
#
#       Account_ACC3000002  Account_ACC4000001  Account Type_Asset  \
# 0                  False               False               False
# 1                  False               False               False
# 2                  False               False               False
# 3                  False               False               False
# 4                  False               False               False
# ...                  ...                 ...                 ...
# 4207               False               False               False
# 4208               False               False                True
# 4209               False               False                True
# 4210                True               False                True
# 4211               False                True               False
#
#       Account Type_Expense  Account Type_Liability  Account Type_Revenue
# 0                    False                   False                  True
# 1                    False                   False                  True
# 2                    False                   False                  True
# 3                    False                   False                  True
# 4                     True                   False                 False
# ...                    ...                     ...                   ...
# 4207                  True                   False                 False
# 4208                 False                   False                 False
# 4209                 False                   False                 False
# 4210                 False                   False                 False
# 4211                 False                    True                 False
#
# [4212 rows x 42 columns]

# %%
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#      Amount  Year_2019  Year_2020  Year_2021  Month_Apr  Month_Aug  Month_Dec  \
# 0  1344.051       True      False      False      False      False      False
# 1   480.968       True      False      False      False      False      False
# 2   650.820       True      False      False      False      False      False
# 3   339.360       True      False      False      False      False      False
# 4  1125.328       True      False      False      False      False      False
#
#    Month_Feb  Month_Jan  Month_Jul  ...  Account_ACC2000003  \
# 0      False       True      False  ...               False
# 1      False       True      False  ...               False
# 2      False       True      False  ...               False
# 3      False       True      False  ...               False
# 4      False       True      False  ...               False
#
#    Account_ACC2000005  Account_ACC3000000  Account_ACC3000001  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    Account_ACC3000002  Account_ACC4000001  Account Type_Asset  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    Account Type_Expense  Account Type_Liability  Account Type_Revenue
# 0                 False                   False                  True
# 1                 False                   False                  True
# 2                 False                   False                  True
# 3                 False                   False                  True
# 4                  True                   False                 False
#
# [5 rows x 42 columns]

# %%
df.dtypes
# Out:
# Amount                    float64
# Year_2019                    bool
# Year_2020                    bool
# Year_2021                    bool
# Month_Apr                    bool
# Month_Aug                    bool
# Month_Dec                    bool
# Month_Feb                    bool
# Month_Jan                    bool
# Month_Jul                    bool
# Month_Jun                    bool
# Month_Mar                    bool
# Month_May                    bool
# Month_Nov                    bool
# Month_Oct                    bool
# Month_Sep                    bool
# Cost Centre_CC100            bool
# Cost Centre_CC101            bool
# Cost Centre_CC102            bool
# Cost Centre_CC200            bool
# Cost Centre_CC201            bool
# Cost Centre_CC202            bool
# Cost Centre_CC300            bool
# Cost Centre_CC301            bool
# Cost Centre_CC302            bool
# Account_ACC1000000           bool
# Account_ACC1000001           bool
# Account_ACC1000002           bool
# Account_ACC1000004           bool
# Account_ACC2000000           bool
# Account_ACC2000001           bool
# Account_ACC2000002           bool
# Account_ACC2000003           bool
# Account_ACC2000005           bool
# Account_ACC3000000           bool
# Account_ACC3000001           bool
# Account_ACC3000002           bool
# Account_ACC4000001           bool
# Account Type_Asset           bool
# Account Type_Expense         bool
# Account Type_Liability       bool
# Account Type_Revenue         bool
# dtype: object

# %%
X = df.drop('Amount', axis=1)
y = df['Amount']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=1234)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (2948, 41) (1264, 41) (2948,) (1264,)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# %%
pipelines = {
    'rf':make_pipeline(RandomForestRegressor(random_state=1234)),
    'gb':make_pipeline(GradientBoostingRegressor(random_state=1234)),
    'ridge':make_pipeline(Ridge(random_state=1234)),
    'lasso':make_pipeline(Lasso(random_state=1234)),
    'enet':make_pipeline(ElasticNet(random_state=1234)),
}

# %%
RandomForestRegressor().get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
hypergrid = {
    'rf': {
        'randomforestregressor__min_samples_split':[2,4,6],
        'randomforestregressor__min_samples_leaf':[1,2,3]
    },
    'gb':{
        'gradientboostingregressor__alpha':[0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 0.99]
    },
    'ridge':{
        'ridge__alpha':[0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 0.99]
    },
    'lasso':{
        'lasso__alpha':[0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 0.99]
    },
    'enet':{
        'elasticnet__alpha':[0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 0.99]
    }
}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.exceptions import NotFittedError

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = GridSearchCV(pipeline, hypergrid[algo], cv=10, n_jobs=-1)
    try:
        print('Starting training for {}.'.format(algo))
        model.fit(X_train, y_train)
        fit_models[algo] = model
        print('{} has been successfully fit.'.format(algo))
    except NotFittedError as e:
        print(repr(e))
# Out:
# Starting training for rf.
# rf has been successfully fit.
# Starting training for gb.
# gb has been successfully fit.
# Starting training for ridge.
# ridge has been successfully fit.
# Starting training for lasso.
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.224e+07, tolerance: 6.519e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.178e+07, tolerance: 6.457e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.291e+07, tolerance: 6.673e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.245e+07, tolerance: 6.411e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.382e+07, tolerance: 6.618e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.426e+07, tolerance: 6.693e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.387e+07, tolerance: 6.520e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.323e+07, tolerance: 6.561e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.297e+07, tolerance: 6.693e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.325e+06, tolerance: 6.457e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.473e+07, tolerance: 6.411e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.445e+07, tolerance: 6.519e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.401e+07, tolerance: 6.673e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.560e+07, tolerance: 6.520e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.318e+07, tolerance: 6.573e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.309e+07, tolerance: 6.461e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.537e+07, tolerance: 6.618e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.504e+07, tolerance: 6.573e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.781e+06, tolerance: 6.673e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.930e+06, tolerance: 6.693e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.212e+06, tolerance: 6.457e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.755e+06, tolerance: 6.618e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.485e+07, tolerance: 6.561e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.912e+06, tolerance: 6.573e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.959e+06, tolerance: 6.519e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.503e+07, tolerance: 6.461e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.757e+06, tolerance: 6.411e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.137e+06, tolerance: 6.520e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.649e+06, tolerance: 6.561e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.712e+06, tolerance: 6.461e+04
#   model = cd_fast.enet_coordinate_descent(
# lasso has been successfully fit.
# Starting training for enet.
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.581e+07, tolerance: 6.457e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.577e+07, tolerance: 6.561e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.963e+07, tolerance: 6.693e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.900e+07, tolerance: 6.520e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.750e+07, tolerance: 6.673e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.645e+07, tolerance: 6.519e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.771e+07, tolerance: 6.618e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.695e+07, tolerance: 6.411e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.735e+07, tolerance: 6.573e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/huzefatapya/radioconda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.653e+07, tolerance: 6.461e+04
#   model = cd_fast.enet_coordinate_descent(
# enet has been successfully fit.

# %%
fit_models['ridge'].predict(X_test)
# Out:
# array([ 526.45072362,  508.65685547,  465.37890944, ..., -297.09355664,
#         708.13679594,  621.74398962])

# %%
from sklearn.metrics import r2_score, mean_absolute_error

# %%
for algo,model in fit_models.items():
    yhat = model.predict(X_test)
    print('{} scores - R2:{} MAE:{}'.format(algo, r2_score(y_test, yhat), mean_absolute_error(y_test, yhat)))
# Out:
# rf scores - R2:0.933891732946942 MAE:76.46670541139243
# gb scores - R2:0.6353516501682552 MAE:190.8419509203904
# ridge scores - R2:0.5093625023110634 MAE:224.8870632810303
# lasso scores - R2:0.509750861393047 MAE:224.4782275114179
# enet scores - R2:0.5086617173444186 MAE:225.02988780517322

# %%
best_model = fit_models['rf']

# %%
creds = {
  "YOUR CREDS HERE"
}

# %%
# !pip install -U ibm-watson-machine-learning
# Out:
# Collecting ibm-watson-machine-learning
#   Downloading ibm_watson_machine_learning-1.0.367-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: requests in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from ibm-watson-machine-learning) (2.32.2)
# Requirement already satisfied: urllib3 in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from ibm-watson-machine-learning) (2.1.0)
# Collecting pandas<2.2.0,>=0.24.2 (from ibm-watson-machine-learning)
#   Downloading pandas-2.1.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (18 kB)
# Requirement already satisfied: certifi in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from ibm-watson-machine-learning) (2023.11.17)
# Requirement already satisfied: lomond in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from ibm-watson-machine-learning) (0.3.3)
# Requirement already satisfied: tabulate in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from ibm-watson-machine-learning) (0.9.0)
# Requirement already satisfied: packaging in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from ibm-watson-machine-learning) (23.2)
# Collecting ibm-cos-sdk<2.14.0,>=2.12.0 (from ibm-watson-machine-learning)
#   Downloading ibm-cos-sdk-2.13.6.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: importlib-metadata in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from ibm-watson-machine-learning) (7.0.1)
# Collecting ibm-cos-sdk-core==2.13.6 (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning)
#   Downloading ibm-cos-sdk-core-2.13.6.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting ibm-cos-sdk-s3transfer==2.13.6 (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning)
#   Downloading ibm-cos-sdk-s3transfer-2.13.6.tar.gz (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.5/139.5 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning) (2.9.0.post0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watson-machine-learning) (1.26.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watson-machine-learning) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watson-machine-learning) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from requests->ibm-watson-machine-learning) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from requests->ibm-watson-machine-learning) (3.6)
# Requirement already satisfied: zipp>=0.5 in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from importlib-metadata->ibm-watson-machine-learning) (3.17.0)
# Requirement already satisfied: six>=1.10.0 in /Users/huzefatapya/radioconda/lib/python3.10/site-packages (from lomond->ibm-watson-machine-learning) (1.16.0)
# Downloading ibm_watson_machine_learning-1.0.367-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 4.1 MB/s eta 0:00:00a 0:00:01
# Downloading pandas-2.1.4-cp310-cp310-macosx_11_0_arm64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 1.7 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: ibm-cos-sdk, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer
#   Building wheel for ibm-cos-sdk (setup.py) ... done
#   Created wheel for ibm-cos-sdk: filename=ibm_cos_sdk-2.13.6-py3-none-any.whl size=77232 sha256=26b683bd486660a75264357757affb5495f7eb0bcfbaed00ecd0f5c106ffbf71
#   Stored in directory: /Users/huzefatapya/Library/Caches/pip/wheels/c7/c7/ef/c6899afa27e0f60b856525da93758d16b52be89d54852ae906
#   Building wheel for ibm-cos-sdk-core (setup.py) ... one
#   Created wheel for ibm-cos-sdk-core: filename=ibm_cos_sdk_core-2.13.6-py3-none-any.whl size=661462 sha256=0a6e48fb8356e5acd00574f57b45b4280ec237750704201d237ac57d350108f3
#   Stored in directory: /Users/huzefatapya/Library/Caches/pip/wheels/38/6e/9b/27f10308c37a531ffb880add20d61753ca3b2c24034f4530da
#   Building wheel for ibm-cos-sdk-s3transfer (setup.py) ... done
#   Created wheel for ibm-cos-sdk-s3transfer: filename=ibm_cos_sdk_s3transfer-2.13.6-py3-none-any.whl size=90203 sha256=bd2cc943a3c395a7f2334114414bf6ad11f51360fb7652af6041c665c2bbb89a
#   Stored in directory: /Users/huzefatapya/Library/Caches/pip/wheels/81/11/8e/5cc3f2d57d16951d4a7b15995338e3bd21b71cded6b9494fb2
# Successfully built ibm-cos-sdk ibm-cos-sdk-core ibm-cos-sdk-s3transfer
# Installing collected packages: pandas, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer, ibm-cos-sdk, ibm-watson-machine-learning
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.0
#     Uninstalling pandas-2.2.0:
#       Successfully uninstalled pandas-2.2.0
#   Attempting uninstall: ibm-cos-sdk-core
#     Found existing installation: ibm-cos-sdk-core 2.14.0
#     Uninstalling ibm-cos-sdk-core-2.14.0:
#       Successfully uninstalled ibm-cos-sdk-core-2.14.0
#   Attempting uninstall: ibm-cos-sdk-s3transfer
#     Found existing installation: ibm-cos-sdk-s3transfer 2.14.0
#     Uninstalling ibm-cos-sdk-s3transfer-2.14.0:
#       Successfully uninstalled ibm-cos-sdk-s3transfer-2.14.0
#   Attempting uninstall: ibm-cos-sdk
#     Found existing installation: ibm-cos-sdk 2.14.0
#     Uninstalling ibm-cos-sdk-2.14.0:
#       Successfully uninstalled ibm-cos-sdk-2.14.0
# Successfully installed ibm-cos-sdk-2.13.6 ibm-cos-sdk-core-2.13.6 ibm-cos-sdk-s3transfer-2.13.6 ibm-watson-machine-learning-1.0.367 pandas-2.1.4

# %%
from ibm_watson_machine_learning import APIClient
import json
import numpy as np

# %%
wml_credentials = {
    "apikey": "_Xi4gTh7W8l9uqC3SH1Uqdii5Vg1SeokuF2zqtYlngnt",
    "url" : "https://us-south.ml.cloud.ibm.com"
}

# %%
wml_client = APIClient(wml_credentials)
wml_client.spaces.list()
# Out:
# Note: 'limit' is not provided. Only first 50 records will be displayed if the number of records exceed 50
# ------------------------------------  ----  ------------------------
# ID                                    NAME  CREATED
# 43475dae-47cd-4f35-8576-5d85a308dac9  PROD  2024-12-16T01:29:06.064Z
# ------------------------------------  ----  ------------------------
#                                      ID  NAME                   CREATED
# 0  43475dae-47cd-4f35-8576-5d85a308dac9  PROD  2024-12-16T01:29:06.064Z

# %%
SPACE_ID="43475dae-47cd-4f35-8576-5d85a308dac9"

# %%
wml_client.set.default_space(SPACE_ID)
# Out:
# 'SUCCESS'

# %%
# Specify Model Constants
MODEL_NAME = 'Sklearn Forecast'
DEPLOYMENT_NAME = 'Sklearn Deployment'
BEST_MODEL = best_model

# %%
# List all software specifications available in your IBM Watson instance
software_specs = wml_client.software_specifications.list()
# Out:
# ----------------------------  ------------------------------------  ----  ------------  --------------------------
# NAME                          ID                                    TYPE  STATE         REPLACEMENT
# default_py3.6                 0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base  retired       runtime-24.1-py3.11
# autoai-ts_rt23.1-py3.10       01ce9391-1a79-5a33-94fb-2e134337f314  base  constricted   autoai-ts_rt24.1-py3.11
# kernel-spark3.2-scala2.12     020d69ce-7ac1-5e68-ac1a-31189867356a  base  retired
# pytorch-onnx_1.3-py3.7-edt    069ea134-3346-5748-b513-49120e15d288  base  retired
# tensorflow_rt23.1-py3.10      079a91e0-245f-5269-8926-3c20b28f37dc  base  constricted   tensorflow_rt24.1-py3.11
# scikit-learn_0.20-py3.6       09c5a1d0-9c1e-4473-a344-eb7b665ff687  base  retired       runtime-24.1-py3.11
# spark-mllib_3.0-scala_2.12    09f4cff0-90a7-5899-b9ed-1ef348aebdee  base  retired
# pytorch-onnx_rt22.1-py3.9     0b848dd4-e681-5599-be41-b5f6fccc6471  base  retired       pytorch-onnx_rt24.1-py3.11
# ai-function_0.1-py3.6         0cdb0f1e-5376-4f4d-92dd-da3b69aa9bda  base  retired       runtime-24.1-py3.11
# watsonx-cfm-caikit-1.0        0cee3c55-472f-57b1-84bd-72f5d066dbe4  base  not_provided
# shiny-r3.6                    0e6e79df-875e-4f24-8ae9-62dcc2148306  base  retired
# tensorflow_2.4-py3.7-horovod  1092590a-307d-563d-9b62-4eb7d64b3f22  base  retired       tensorflow_rt24.1-py3.11
# pytorch_1.1-py3.6             10ac12d6-6b30-4ccd-8392-3e922c096a92  base  retired       runtime-24.1-py3.11
# tensorflow_1.15-py3.6-ddl     111e41b3-de2d-5422-a4d6-bf776828c4b7  base  retired
# autoai-kb_rt22.2-py3.10       125b6d9a-5b1f-5e8d-972a-b251688ccf40  base  retired       autoai-kb_rt24.1-py3.11
# watsonx-textgen-fm-1.0        129aec82-7e65-5c78-b812-4c0a74b916f5  base  not_provided
# runtime-22.1-py3.9            12b83a17-24d8-5082-900f-0ab31fbfd3cb  base  retired       runtime-24.1-py3.11
# masking-flows-spark           13666829-5570-53a7-927b-52d42a101d93  base  not_provided
# kernel-spark3.3-py3.10        147e6777-ccd1-5886-8571-5356abc20839  base  retired
# scikit-learn_0.22-py3.6       154010fa-5b3b-4ac1-82af-4d5ee5abbc85  base  retired       runtime-24.1-py3.11
# pytorch-onnx_rt23.1-py3.10    195067e6-4c5e-5fab-8bd0-e7623a88b4d3  base  constricted   pytorch-onnx_rt24.1-py3.11
# default_r3.6                  1b70aec3-ab34-4b87-8aa0-a4a3c8296a36  base  retired
# pytorch-onnx_1.3-py3.6        1bc6029a-cc97-56da-b8e0-39c3880dbbe7  base  retired       runtime-24.1-py3.11
# kernel-spark3.3-r3.6          1c9e5454-f216-59dd-a20e-474a5cdf5988  base  retired
# tensorflow_2.1-py3.6          1eb25b84-d6ed-5dde-b6a5-3fbdf1665666  base  retired       runtime-24.1-py3.11
# spark-mllib_3.2               20047f72-0a98-58c7-9ff5-a77b012eb8f5  base  retired       spark-mllib_3.3
# tensorflow_2.4-py3.8-horovod  217c16f6-178f-56bf-824a-b19f20564c49  base  retired       tensorflow_rt24.1-py3.11
# runtime-22.1-py3.9-cuda       26215f05-08c3-5a41-a1b0-da66306ce658  base  retired       runtime-24.1-py3.11-cuda
# do_py3.8                      295addb5-9ef9-547e-9bf4-92ae3563e720  base  retired
# autoai-ts_3.8-py3.8           2aa0c932-798f-5ae9-abd6-15e0c2402fb5  base  retired       autoai-ts_rt24.1-py3.11
# tensorflow_1.15-py3.6         2b73a275-7cbf-420b-a912-eae7f436e0bc  base  retired       runtime-24.1-py3.11
# kernel-spark3.3-py3.9         2b7961e2-e3b1-5a8c-a491-482c8368839a  base  retired
# tensorflow_rt24.1-py3.11      2c33167d-b11c-5490-a305-3e5e95db5c4d  base  supported
# pytorch_1.2-py3.6             2c8ef57d-2687-4b7d-acce-01f94976dac1  base  retired       runtime-24.1-py3.11
# pytorch-onnx_rt24.1-py3.11    2da185aa-eac3-59a5-bb8e-0e5b60458a15  base  supported
# spark-mllib_2.3               2e51f700-bca0-4b0d-88dc-5c6791338875  base  retired       spark-mllib_3.3
# pytorch-onnx_1.1-py3.6-edt    32983cea-3f32-4400-8965-dde874a8d67e  base  retired       runtime-24.1-py3.11
# runtime-23.1-py3.10           336b29df-e0e1-5e7d-b6a5-f6ab722625b2  base  constricted   runtime-24.1-py3.11
# spark-mllib_3.0-py37          36507ebe-8770-55ba-ab2a-eafe787600e9  base  retired       spark-mllib_3.3
# onnxruntime_opset_19          368d2795-aaa7-59a0-834c-248c64a5a99e  base  supported
# runtime-24.1-py3.11-xc        36e20eca-b269-5e53-8f76-559f5cf898f2  base  not_provided
# spark-mllib_2.4               390d21f8-e58b-4fac-9c55-d7ceda621326  base  retired       spark-mllib_3.3
# autoai-ts_rt22.2-py3.10       396b2e83-0953-5b86-9a55-7ce1628a406f  base  retired       autoai-ts_rt24.1-py3.11
# xgboost_0.82-py3.6            39e31acd-5f30-41dc-ae44-60233c80306e  base  retired       runtime-24.1-py3.11
# pytorch-onnx_1.2-py3.6-edt    40589d0e-7019-4e28-8daa-fb03b6f4fe12  base  retired       runtime-24.1-py3.11
# pytorch-onnx_rt22.2-py3.10    40e73f55-783a-5535-b3fa-0c8b94291431  base  retired       pytorch-onnx_rt24.1-py3.11
# default_r36py38               41c247d3-45f8-5a71-b065-8580229facf0  base  retired
# autoai-ts_rt22.1-py3.9        4269d26e-07ba-5d40-8f66-2d495b0c71f7  base  retired       autoai-ts_rt24.1-py3.11
# autoai-obm_3.0                42b92e18-d9ab-567f-988a-4240ba1ed5f7  base  retired       autoai-obm_3.2
# runtime-24.1-py3.11           45f12dfe-aa78-5b8d-9f38-0ee223c47309  base  supported
# ----------------------------  ------------------------------------  ----  ------------  --------------------------
# Note: Only first 50 records were displayed. To display more use 'limit' parameter.

# %%
wml_client.repository.list_models()
# Out:
# --  ----  -------  ----  ----------  ----------------
# ID  NAME  CREATED  TYPE  SPEC_STATE  SPEC_REPLACEMENT
# --  ----  -------  ----  ----------  ----------------
# Empty DataFrame
# Columns: [ID, NAME, CREATED, TYPE, SPEC_STATE, SPEC_REPLACEMENT]
# Index: []

# %%
wml_client.repository.ModelMetaNames.TYPE  # Optional if wml_client.software_specifications.list() works
wml_client.software_specifications.list()
# Out:
# ----------------------------  ------------------------------------  ----  ------------  --------------------------
# NAME                          ID                                    TYPE  STATE         REPLACEMENT
# default_py3.6                 0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base  retired       runtime-24.1-py3.11
# autoai-ts_rt23.1-py3.10       01ce9391-1a79-5a33-94fb-2e134337f314  base  constricted   autoai-ts_rt24.1-py3.11
# kernel-spark3.2-scala2.12     020d69ce-7ac1-5e68-ac1a-31189867356a  base  retired
# pytorch-onnx_1.3-py3.7-edt    069ea134-3346-5748-b513-49120e15d288  base  retired
# tensorflow_rt23.1-py3.10      079a91e0-245f-5269-8926-3c20b28f37dc  base  constricted   tensorflow_rt24.1-py3.11
# scikit-learn_0.20-py3.6       09c5a1d0-9c1e-4473-a344-eb7b665ff687  base  retired       runtime-24.1-py3.11
# spark-mllib_3.0-scala_2.12    09f4cff0-90a7-5899-b9ed-1ef348aebdee  base  retired
# pytorch-onnx_rt22.1-py3.9     0b848dd4-e681-5599-be41-b5f6fccc6471  base  retired       pytorch-onnx_rt24.1-py3.11
# ai-function_0.1-py3.6         0cdb0f1e-5376-4f4d-92dd-da3b69aa9bda  base  retired       runtime-24.1-py3.11
# watsonx-cfm-caikit-1.0        0cee3c55-472f-57b1-84bd-72f5d066dbe4  base  not_provided
# shiny-r3.6                    0e6e79df-875e-4f24-8ae9-62dcc2148306  base  retired
# tensorflow_2.4-py3.7-horovod  1092590a-307d-563d-9b62-4eb7d64b3f22  base  retired       tensorflow_rt24.1-py3.11
# pytorch_1.1-py3.6             10ac12d6-6b30-4ccd-8392-3e922c096a92  base  retired       runtime-24.1-py3.11
# tensorflow_1.15-py3.6-ddl     111e41b3-de2d-5422-a4d6-bf776828c4b7  base  retired
# autoai-kb_rt22.2-py3.10       125b6d9a-5b1f-5e8d-972a-b251688ccf40  base  retired       autoai-kb_rt24.1-py3.11
# watsonx-textgen-fm-1.0        129aec82-7e65-5c78-b812-4c0a74b916f5  base  not_provided
# runtime-22.1-py3.9            12b83a17-24d8-5082-900f-0ab31fbfd3cb  base  retired       runtime-24.1-py3.11
# masking-flows-spark           13666829-5570-53a7-927b-52d42a101d93  base  not_provided
# kernel-spark3.3-py3.10        147e6777-ccd1-5886-8571-5356abc20839  base  retired
# scikit-learn_0.22-py3.6       154010fa-5b3b-4ac1-82af-4d5ee5abbc85  base  retired       runtime-24.1-py3.11
# pytorch-onnx_rt23.1-py3.10    195067e6-4c5e-5fab-8bd0-e7623a88b4d3  base  constricted   pytorch-onnx_rt24.1-py3.11
# default_r3.6                  1b70aec3-ab34-4b87-8aa0-a4a3c8296a36  base  retired
# pytorch-onnx_1.3-py3.6        1bc6029a-cc97-56da-b8e0-39c3880dbbe7  base  retired       runtime-24.1-py3.11
# kernel-spark3.3-r3.6          1c9e5454-f216-59dd-a20e-474a5cdf5988  base  retired
# tensorflow_2.1-py3.6          1eb25b84-d6ed-5dde-b6a5-3fbdf1665666  base  retired       runtime-24.1-py3.11
# spark-mllib_3.2               20047f72-0a98-58c7-9ff5-a77b012eb8f5  base  retired       spark-mllib_3.3
# tensorflow_2.4-py3.8-horovod  217c16f6-178f-56bf-824a-b19f20564c49  base  retired       tensorflow_rt24.1-py3.11
# runtime-22.1-py3.9-cuda       26215f05-08c3-5a41-a1b0-da66306ce658  base  retired       runtime-24.1-py3.11-cuda
# do_py3.8                      295addb5-9ef9-547e-9bf4-92ae3563e720  base  retired
# autoai-ts_3.8-py3.8           2aa0c932-798f-5ae9-abd6-15e0c2402fb5  base  retired       autoai-ts_rt24.1-py3.11
# tensorflow_1.15-py3.6         2b73a275-7cbf-420b-a912-eae7f436e0bc  base  retired       runtime-24.1-py3.11
# kernel-spark3.3-py3.9         2b7961e2-e3b1-5a8c-a491-482c8368839a  base  retired
# tensorflow_rt24.1-py3.11      2c33167d-b11c-5490-a305-3e5e95db5c4d  base  supported
# pytorch_1.2-py3.6             2c8ef57d-2687-4b7d-acce-01f94976dac1  base  retired       runtime-24.1-py3.11
# pytorch-onnx_rt24.1-py3.11    2da185aa-eac3-59a5-bb8e-0e5b60458a15  base  supported
# spark-mllib_2.3               2e51f700-bca0-4b0d-88dc-5c6791338875  base  retired       spark-mllib_3.3
# pytorch-onnx_1.1-py3.6-edt    32983cea-3f32-4400-8965-dde874a8d67e  base  retired       runtime-24.1-py3.11
# runtime-23.1-py3.10           336b29df-e0e1-5e7d-b6a5-f6ab722625b2  base  constricted   runtime-24.1-py3.11
# spark-mllib_3.0-py37          36507ebe-8770-55ba-ab2a-eafe787600e9  base  retired       spark-mllib_3.3
# onnxruntime_opset_19          368d2795-aaa7-59a0-834c-248c64a5a99e  base  supported
# runtime-24.1-py3.11-xc        36e20eca-b269-5e53-8f76-559f5cf898f2  base  not_provided
# spark-mllib_2.4               390d21f8-e58b-4fac-9c55-d7ceda621326  base  retired       spark-mllib_3.3
# autoai-ts_rt22.2-py3.10       396b2e83-0953-5b86-9a55-7ce1628a406f  base  retired       autoai-ts_rt24.1-py3.11
# xgboost_0.82-py3.6            39e31acd-5f30-41dc-ae44-60233c80306e  base  retired       runtime-24.1-py3.11
# pytorch-onnx_1.2-py3.6-edt    40589d0e-7019-4e28-8daa-fb03b6f4fe12  base  retired       runtime-24.1-py3.11
# pytorch-onnx_rt22.2-py3.10    40e73f55-783a-5535-b3fa-0c8b94291431  base  retired       pytorch-onnx_rt24.1-py3.11
# default_r36py38               41c247d3-45f8-5a71-b065-8580229facf0  base  retired
# autoai-ts_rt22.1-py3.9        4269d26e-07ba-5d40-8f66-2d495b0c71f7  base  retired       autoai-ts_rt24.1-py3.11
# autoai-obm_3.0                42b92e18-d9ab-567f-988a-4240ba1ed5f7  base  retired       autoai-obm_3.2
# runtime-24.1-py3.11           45f12dfe-aa78-5b8d-9f38-0ee223c47309  base  supported
# ----------------------------  ------------------------------------  ----  ------------  --------------------------
# Note: Only first 50 records were displayed. To display more use 'limit' parameter.
#                             NAME                                    ID  TYPE  \
# 0                  default_py3.6  0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base
# 1        autoai-ts_rt23.1-py3.10  01ce9391-1a79-5a33-94fb-2e134337f314  base
# 2      kernel-spark3.2-scala2.12  020d69ce-7ac1-5e68-ac1a-31189867356a  base
# 3     pytorch-onnx_1.3-py3.7-edt  069ea134-3346-5748-b513-49120e15d288  base
# 4       tensorflow_rt23.1-py3.10  079a91e0-245f-5269-8926-3c20b28f37dc  base
# 5        scikit-learn_0.20-py3.6  09c5a1d0-9c1e-4473-a344-eb7b665ff687  base
# 6     spark-mllib_3.0-scala_2.12  09f4cff0-90a7-5899-b9ed-1ef348aebdee  base
# 7      pytorch-onnx_rt22.1-py3.9  0b848dd4-e681-5599-be41-b5f6fccc6471  base
# 8          ai-function_0.1-py3.6  0cdb0f1e-5376-4f4d-92dd-da3b69aa9bda  base
# 9         watsonx-cfm-caikit-1.0  0cee3c55-472f-57b1-84bd-72f5d066dbe4  base
# 10                    shiny-r3.6  0e6e79df-875e-4f24-8ae9-62dcc2148306  base
# 11  tensorflow_2.4-py3.7-horovod  1092590a-307d-563d-9b62-4eb7d64b3f22  base
# 12             pytorch_1.1-py3.6  10ac12d6-6b30-4ccd-8392-3e922c096a92  base
# 13     tensorflow_1.15-py3.6-ddl  111e41b3-de2d-5422-a4d6-bf776828c4b7  base
# 14       autoai-kb_rt22.2-py3.10  125b6d9a-5b1f-5e8d-972a-b251688ccf40  base
# 15        watsonx-textgen-fm-1.0  129aec82-7e65-5c78-b812-4c0a74b916f5  base
# 16            runtime-22.1-py3.9  12b83a17-24d8-5082-900f-0ab31fbfd3cb  base
# 17           masking-flows-spark  13666829-5570-53a7-927b-52d42a101d93  base
# 18        kernel-spark3.3-py3.10  147e6777-ccd1-5886-8571-5356abc20839  base
# 19       scikit-learn_0.22-py3.6  154010fa-5b3b-4ac1-82af-4d5ee5abbc85  base
# 20    pytorch-onnx_rt23.1-py3.10  195067e6-4c5e-5fab-8bd0-e7623a88b4d3  base
# 21                  default_r3.6  1b70aec3-ab34-4b87-8aa0-a4a3c8296a36  base
# 22        pytorch-onnx_1.3-py3.6  1bc6029a-cc97-56da-b8e0-39c3880dbbe7  base
# 23          kernel-spark3.3-r3.6  1c9e5454-f216-59dd-a20e-474a5cdf5988  base
# 24          tensorflow_2.1-py3.6  1eb25b84-d6ed-5dde-b6a5-3fbdf1665666  base
# 25               spark-mllib_3.2  20047f72-0a98-58c7-9ff5-a77b012eb8f5  base
# 26  tensorflow_2.4-py3.8-horovod  217c16f6-178f-56bf-824a-b19f20564c49  base
# 27       runtime-22.1-py3.9-cuda  26215f05-08c3-5a41-a1b0-da66306ce658  base
# 28                      do_py3.8  295addb5-9ef9-547e-9bf4-92ae3563e720  base
# 29           autoai-ts_3.8-py3.8  2aa0c932-798f-5ae9-abd6-15e0c2402fb5  base
# 30         tensorflow_1.15-py3.6  2b73a275-7cbf-420b-a912-eae7f436e0bc  base
# 31         kernel-spark3.3-py3.9  2b7961e2-e3b1-5a8c-a491-482c8368839a  base
# 32      tensorflow_rt24.1-py3.11  2c33167d-b11c-5490-a305-3e5e95db5c4d  base
# 33             pytorch_1.2-py3.6  2c8ef57d-2687-4b7d-acce-01f94976dac1  base
# 34    pytorch-onnx_rt24.1-py3.11  2da185aa-eac3-59a5-bb8e-0e5b60458a15  base
# 35               spark-mllib_2.3  2e51f700-bca0-4b0d-88dc-5c6791338875  base
# 36    pytorch-onnx_1.1-py3.6-edt  32983cea-3f32-4400-8965-dde874a8d67e  base
# 37           runtime-23.1-py3.10  336b29df-e0e1-5e7d-b6a5-f6ab722625b2  base
# 38          spark-mllib_3.0-py37  36507ebe-8770-55ba-ab2a-eafe787600e9  base
# 39          onnxruntime_opset_19  368d2795-aaa7-59a0-834c-248c64a5a99e  base
# 40        runtime-24.1-py3.11-xc  36e20eca-b269-5e53-8f76-559f5cf898f2  base
# 41               spark-mllib_2.4  390d21f8-e58b-4fac-9c55-d7ceda621326  base
# 42       autoai-ts_rt22.2-py3.10  396b2e83-0953-5b86-9a55-7ce1628a406f  base
# 43            xgboost_0.82-py3.6  39e31acd-5f30-41dc-ae44-60233c80306e  base
# 44    pytorch-onnx_1.2-py3.6-edt  40589d0e-7019-4e28-8daa-fb03b6f4fe12  base
# 45    pytorch-onnx_rt22.2-py3.10  40e73f55-783a-5535-b3fa-0c8b94291431  base
# 46               default_r36py38  41c247d3-45f8-5a71-b065-8580229facf0  base
# 47        autoai-ts_rt22.1-py3.9  4269d26e-07ba-5d40-8f66-2d495b0c71f7  base
# 48                autoai-obm_3.0  42b92e18-d9ab-567f-988a-4240ba1ed5f7  base
# 49           runtime-24.1-py3.11  45f12dfe-aa78-5b8d-9f38-0ee223c47309  base
#
#            STATE                 REPLACEMENT
# 0        retired         runtime-24.1-py3.11
# 1    constricted     autoai-ts_rt24.1-py3.11
# 2        retired
# 3        retired
# 4    constricted    tensorflow_rt24.1-py3.11
# 5        retired         runtime-24.1-py3.11
# 6        retired
# 7        retired  pytorch-onnx_rt24.1-py3.11
# 8        retired         runtime-24.1-py3.11
# 9   not_provided
# 10       retired
# 11       retired    tensorflow_rt24.1-py3.11
# 12       retired         runtime-24.1-py3.11
# 13       retired
# 14       retired     autoai-kb_rt24.1-py3.11
# 15  not_provided
# 16       retired         runtime-24.1-py3.11
# 17  not_provided
# 18       retired
# 19       retired         runtime-24.1-py3.11
# 20   constricted  pytorch-onnx_rt24.1-py3.11
# 21       retired
# 22       retired         runtime-24.1-py3.11
# 23       retired
# 24       retired         runtime-24.1-py3.11
# 25       retired             spark-mllib_3.3
# 26       retired    tensorflow_rt24.1-py3.11
# 27       retired    runtime-24.1-py3.11-cuda
# 28       retired
# 29       retired     autoai-ts_rt24.1-py3.11
# 30       retired         runtime-24.1-py3.11
# 31       retired
# 32     supported
# 33       retired         runtime-24.1-py3.11
# 34     supported
# 35       retired             spark-mllib_3.3
# 36       retired         runtime-24.1-py3.11
# 37   constricted         runtime-24.1-py3.11
# 38       retired             spark-mllib_3.3
# 39     supported
# 40  not_provided
# 41       retired             spark-mllib_3.3
# 42       retired     autoai-ts_rt24.1-py3.11
# 43       retired         runtime-24.1-py3.11
# 44       retired         runtime-24.1-py3.11
# 45       retired  pytorch-onnx_rt24.1-py3.11
# 46       retired
# 47       retired     autoai-ts_rt24.1-py3.11
# 48       retired              autoai-obm_3.2
# 49     supported

# %%
software_spec_uid = wml_client.software_specifications.get_id_by_name('default_py3.10')

model_props = {
    wml_client.repository.ModelMetaNames.NAME: MODEL_NAME,
    wml_client.repository.ModelMetaNames.TYPE: TYPE,
    wml_client.repository.ModelMetaNames.SOFTWARE_SPEC_UID: software_spec_uid
}

published_model_details = wml_client.repository.store_model(
    model=BEST_MODEL, 
    meta_props=model_props, 
    training_data=X_train, 
    training_target=y_train, 
    pipeline=pipelines['rf']
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[283], line 5
#       1 software_spec_uid = wml_client.software_specifications.get_id_by_name('default_py3.10')
#       3 model_props = {
#       4     wml_client.repository.ModelMetaNames.NAME: MODEL_NAME,
# ----> 5     wml_client.repository.ModelMetaNames.TYPE: TYPE,
#       6     wml_client.repository.ModelMetaNames.SOFTWARE_SPEC_UID: software_spec_uid
#       7 }
#       9 published_model_details = wml_client.repository.store_model(
#      10     model=BEST_MODEL,
#      11     meta_props=model_props,
#    (...)
#      14     pipeline=pipelines['rf']
#      15 )
#
# NameError: name 'TYPE' is not defined

# %%
model_uid = wml_client.repository.get_model_uid(published_model_details)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[275], line 1
# ----> 1 model_uid = wml_client.repository.get_model_uid(published_model_details)
#
# NameError: name 'published_model_details' is not defined

# %%
model_uid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[259], line 1
# ----> 1 model_uid
#
# NameError: name 'model_uid' is not defined

# %%
deployment = wml_client.deployments.create(artifact_uid=model_uid, name=DEPLOYMENT_NAME, asynchronous=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[260], line 1
# ----> 1 deployment = wml_client.deployments.create(artifact_uid=model_uid, name=DEPLOYMENT_NAME, asynchronous=False)
#
# NameError: name 'model_uid' is not defined

# %%
# Get deployment stuff
iam_token = wml_client.wml_token
ml_instance_id = creds['instance_id']
url = deployment['entity']['scoring_url']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[261], line 3
#       1 # Get deployment stuff
#       2 iam_token = wml_client.wml_token
# ----> 3 ml_instance_id = creds['instance_id']
#       4 url = deployment['entity']['scoring_url']
#
# TypeError: 'set' object is not subscriptable

# %%
deployment

# %%
X_test.columns.to_numpy().tolist()

# %%
X_test.iloc[0].to_numpy().tolist()

# %%
import urllib3, requests, json

# %%
header = {'Content-Type':'application/json', 'Authorization':'Bearer '+iam_token, 'ML-Instance-ID':ml_instance_id}
payload = {'fields':X_test.columns.to_numpy().tolist(), "values":X_test.to_numpy().tolist()}

# %%
payload

# %%
response_scoring = requests.post(url, json=payload, headers=header)

# %%
response_scoring

# %%
response_scoring.text

# %%
predictions = json.loads(response_scoring.text)

# %%
import numpy as np

# %%
pred_values = np.squeeze(predictions['values'])

# %%
pred_values

# %%
preddf = X_test.join(y_test)

# %%
preddf['Scores'] = pred_values

# %%
preddf.head()

# %%
preddf['Diff'] = preddf['Amount'] - preddf['Scores']

# %%
preddf.head()

# %%
preddf.to_csv('results.csv')

# %%
X_test[['Account Type_Asset',  'Account Type_Expense',  'Account Type_Liability',  'Account Type_Revenue']][X_test['Account_ACC3000000']==1].head()

# %%
X_test.iloc[0].to_numpy().tolist()
